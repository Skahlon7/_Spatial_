# %% [markdown]
# **<h3>DSCI 510: Principles of Programming for Data Science </h3>**
# <h4>Spring 2023 – Assignment 15</h4>
#
# Instructor: <a href="mailto:ambite@isi.edu">Prof. Jose Luis Ambite </a>
# Course Producers: <a href="mailto:svara@usc.edu">Samuel Vara</a>, <a href="mailto:svparakh@usc.edu">Sanjana Parakh</a>, <a href="mailto:swarnita@usc.edu">Swarnita Venkatraman</a>, <a href="mailto:gursimar@usc.edu">Gursimar Kaur</a>
# </h2>

# %% [markdown]
# **Guidelines for the Assignment:**
#
# - You have to complete the assignments individually. If you are having trouble completing the assignment do let the TAs know/post on Piazza.
#
# - Please don't copy code (either partially/fully) from your classmates. Plagiarism of any form will result in a 0 and you will be reported to SJACS (https://sjacs.usc.edu/students/academic-integrity/).
#
# - You have to fill the code in this notebook and upload it for submission. While doing this, make sure all supporting files that you download from D2L are in the same directory as this notebook.
#
# - File Naming Convention : Lab15_LastName_FirstName.ipynb
#
# - Don't change existing methods (if any, unless otherwise mentioned in the instructions)
#
# - You are encouraged to look up resources online like python docs and stackoverflow. Look up the topics and not the questions themselves.
#
# - Your last submission before the deadline will be counted towards your grade. You can submit any number of times before the deadline.
#
# - You need to take input from file/console only if it is mentioned in the question. If not we need just the logic/implementation of your function.
#
# - Scores are capped at 10 points including the Bonus problem. For Example: Even if you get a score of 12/10, your score is capped at 10.
#
# - Bonus score is counted only if the first 2 questions are attempted. Don't attempt the bonus question if you haven't attempted the first 2.
#
# ----------------------------------------------

# %% [markdown]
# ## **Question 1 - GDP trend of three countries in Africa[4 points]**
#
# You are provided with a csv dataset 'gapminder_data_graphs.csv'. More details about the dataset as mentioned on https://www.kaggle.com/datasets/albertovidalrod/gapminder-dataset:
#
# This data set has been generated using data from the Gapminder website, which focuses on gathering and sharing statistics and other information about social, economic and environmental development at local, national and global levels. This particular data set describes the values of several parameters (see the list below) between 1998 and 2018 for a total of 175 countries, having a total of 3675 rows. The parameters included in the data set and the column name of the dataframe are as follows:
#
# * Country (country). Describes the country name
# * Continent (continent). Describes the continent to which the country belongs
# * Year (year). Describes the year to which the data belongs
# * Life expectancy (life_exp). Describes the life expectancy for a given country in a given year
# * Human Development Index (hdi_index). Describes the HDI index value for a given country in a given year
# * CO2 emissions per person(co2_consump). Describes the CO2 emissions in tonnes per person for a given country in a given year
# * Gross Domestic Product per capita (gdp). Describes the GDP per capita in dollars for a given country in a given year
# * % Service workers (services). Describes the the % of service workers for a given country in a given year
#
#
# **Tips for this Assignment:**
#
# 1. Write your observations down under each plot. Even though you are not being graded on that aspect it is good practice to write down what insights you can deduce from each plot.
# 2. There are no restrictions on colors/styling of any of the plots, if you are meeting the expected criteria as per output shown it would be enough. The plots and values must be correct.
#
# **Helpful Links for this Assignment:**
#
# * Data Visualization cheat sheet: https://jovian.ml/aakashns/dataviz-cheatsheet
# * Seaborn gallery: https://seaborn.pydata.org/examples/index.html
# * Matplotlib gallery: https://matplotlib.org/3.1.1/gallery/index.html
# * Matplotlib tutorial: https://github.com/rougier/matplotlib-tutorial
# ---
#
#
#
# You have to create line plots of the GDP(y-axis) against the year(x-axis) for 3 countries in Africa using Matplotlib in a single plot.
#
# *   The years chosen for this plot should be between 2010 and 2018(both inclusive).
# *   The countries chosen for this plot should be 'Equatorial Guinea', 'Mauritius'and 'Libya'.
# *   marker='o' must be enabled for all the plots.
# *   Legend must be present in the plot to show which line belongs to which conutry.
# *   Label for x-axis must be 'Year', Label for y-axis must be 'Gross Domestic Product per capita (GDP)'.
# *  Title of the plot must be 'GDP trend of three African countries'.
#
# **Expected Output:**
#
#
#
# ![download1.png](data:image/png;base64,...)

# %%
#do not change this cell
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#write your code below
df = pd.read_csv('./gapminder_data_graphs.csv')
df_line = df.query('country.isin(["Equatorial Guinea", "Mauritius", "Libya"]) and year <=2018 and year >=2010 ')

plt.figure(figsize=(10,6))

for country in df_line.country.unique():
    plt.plot(df_line[df_line['country'] == country]['year'], df_line[df_line['country'] == country]['gdp'],
            marker = 'o')

plt.xlabel('Year'), plt.ylabel('Gross Domestic Product per capita (GDP)')
plt.legend([x for x in df_line.country.unique()])
plt.title('GDP trend of three African countries');

# %% [markdown]
# ## **Question 2 - HDI and Life Expectancy Insights for Asian countries[6 points]**
#
# Use the same dataframe created in the first question. You have to create three different plots for this question using Seaborn:
#
# 1. Plot a Scatter plot of hdi_index vs life_exp. Set hue='continent'.
#
# **Expected Output:**
#
# ![download2.png](data:image/png;base64,...)
#
# 2. Find the top 5 countries that had highest hdi_index in 2018 in Asia and plot a bar chart of the life_exp(y-axis) of those 5 countries(x-axis) in 2018.
#
# **Expected Output(The labels for x-axis are not shown here as that would give away the answer):**
#
# ![download3.png](data:image/png;base64,...)
#
# 3. Plot a horizontal(hint: set orient='h') box plot of those 5 countries across all years with the country on y-axis and life_exp on x-axis.
#
# **Expected Output(The labels for y-axis are not shown here as that would give away the answer):**
#
# ![download4.png](data:image/png;base64,...)
#
# Provide appropriate labels for x-axis, y-axis and title.

# %%
#write your code below for Plot 1
plt.figure(figsize=(10,6))
sns.scatterplot(x=df.life_exp, y=df.hdi_index, hue=df.continent)
plt.title('Continent wise HDI vs Life Expectance');

# %%
#write your code below for Plot 2
plt.figure(figsize=(10,6))
df_asia = df.query('continent == "Asia" and year == 2018').sort_values(by='hdi_index', ascending=False).head(5)
sns.barplot(x=df_asia.country, y=df_asia.life_exp);

# %%
#write your code below for Plot 3
plt.figure(figsize=(10,6))
df_box = df[df['country'].isin(df_asia.country.unique())]
sns.boxplot(y=df_box.country, x=df_box.life_exp);

# %% [markdown]
# ## **Bonus Question[5 points]**
#
# Create 2x2 subplot for comparing life expectancy(y-axis) vs Services(x-axis) and GDP(y-axis) vs Services(x-axis) using Matplotlib and Seaborn.
#
#
# *   The years chosen for these plots should be 1998 and 2018.
# *   The continents chosen for these plots should be Europe and Africa (hint: use hue='continent').
# *  Add a global title to the subplot. Check out: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.suptitle.html
# * Provide appropriate labels for x-axis, y-axis and title of each subplot.
#
#
# Row 1,Column 1: Life Expectancy (life_exp) on the y-axis and % Service workers (services) on the x-axis in the year 1998 for both Europe and Africa
#
# Row 1,Column 2: Life Expectancy (life_exp) on the y-axis and % Service workers (services) on the x-axis in the year 2018 for both Europe and Africa
#
# Row 2, Column 1: GDP (gdp) on the y-axis and % Service workers (services) on the x-axis in the year 1998 for both Europe and Africa
#
# Row 2, Column 2: GDP (gdp) on the y-axis and % Service workers (services) on the x-axis in the year 2018 for both Europe and Africa
#
# The top 2 plots of the subplot should be scatter plots and the bottom 2 plots of the subplot should be line plots.
#
# **Expected Output:**
#
# ![download5.png](data:image/png;base64,...)

# %%
#write your code below
#Filter DF
df_1998 = df.query('(continent=="Europe" or continent=="Africa") and year==1998')

fig, axes = plt.subplots(2, 2, figsize=(18, 10))

#plot1 1998 - scatter
axes[0,0].set_title('Life Expectancy (life_exp) vs % Service workers (services) - 1998')
sns.scatterplot(x=df_1998.services, y=df_1998.life_exp, hue=df_1998.continent, ax=axes[0,0])
axes[0,0].set_xlabel('% Service workers (services)')
axes[0,0].set_ylabel('Life Expectancy (life_exp)');

#Plot2 1998 - line
axes[1,0].set_title('GDP (gdp) vs % Service workers (services) - 1998')
sns.lineplot(x=df_1998.services, y=df_1998.gdp, hue = df_1998.continent, ax=axes[1,0])
axes[1,0].set_xlabel('% Service workers (services)')
axes[1,0].set_ylabel('GDP (gdp)');

#plot1 2018 - scatter
df_2018 = df.query('(continent=="Europe" or continent=="Africa") and year==2018')
axes[0,1].set_title('Life Expectancy (life_exp) vs % Service workers (services) - 2018')
sns.scatterplot(x=df_2018.services, y=df_2018.life_exp, hue=df_2018.continent, ax=axes[0,1])
axes[0,1].set_xlabel('% Service workers (services)')
axes[0,1].set_ylabel('Life Expectancy (life_exp)');

#plot2 2018 - line
axes[1,1].set_title('GDP (gdp) vs % Service workers (services) - 2018')
sns.lineplot(x=df_2018.services, y=df_2018.gdp, hue=df_2018.continent)
axes[1,1].set_xlabel('% Service workers (services)')
axes[1,1].set_ylabel('GDP (gdp)');
