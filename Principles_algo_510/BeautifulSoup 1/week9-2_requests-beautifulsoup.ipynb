# %% [markdown]
# # The 'Requests' package & BeautifulSoup

# %% [markdown]
# ## The DOM Tree (Document Object Model)

# %% [markdown]
# Adapted from: http://docs.python-requests.org/en/master/user/quickstart/

# %% [markdown]
# Install __requests__, if it isn't already (I use "pip", e.g. "pip install requests".  You may use git, easy_install, etc.)
#
# Then import the library, like you would any other.

# %%
import requests

# %% [markdown]
# To "get" a webpage (or anything else available via the internet), use requests.get(URL):

# %%
r = requests.get('https://api.github.com/events')

# %% [markdown]
# Now, we have a Response object called r. We can get all the information we need from this object.
#
# (We can use more complex URL encodings, to do HTTP POST calls, or to pass parameters in the URL, but we'll skip those for now)

# %% [markdown]
# Use the .text attribute to get the raw text of the response.
# This will be key when we start parsing/scraping webpages with Beautiful Soup!

# %%
r.text
# Out:
# '[{"id":"27538980347","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":253501538,"name":"EricRicketts/Exercism","url":"https://api.github.com/repos/EricRicketts/Exercism"},"payload":{"action":"opened","number":59,"pull_request":{"url":"https://api.github.com/repos/EricRicketts/Exercism/pulls/59","id":1265729561,"node_id":"PR_kwDODxwgYs5LcYAZ","html_url":"https://github.com/EricRicketts/Exercism/pull/59","diff_url":"https://github.com/EricRicketts/Exercism/pull/59.diff","patch_url":"https://github.com/EricRicketts/Exercism/pull/59.patch","issue_url":"https://api.github.com/repos/EricRicketts/Exercism/issues/59","number":59,"state":"open","locked":false,"title":"Bump minimist from 1.2.5 to 1.2.8 in /javascript/annalyns-infiltration","user":{"login":"dependabot[bot]","id":49699333,"node_id":"MDM6Qm90NDk2OTkzMzM=","avatar_url":"https://avatars.githubusercontent.com/in/29110?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot%5Bbot%5D","html_url":"https://github.com/apps/dependabot","followers_url":"https://api.github.com/users/dependabot%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [minimist](https://github.com/minimistjs/minimist) from 1.2.5 to 1.2.8.\\n<details>\\n<summary>Changelog</summary>\\n<p><em>Sourced from <a href=\\"https://github.com/minimistjs/minimist/blob/main/CHANGELOG.md\\">minimist\'s changelog</a>.</em></p>\\n<blockquote>\\n<h2><a href=\\"https://github.com/minimistjs/minimist/compare/v1.2.7...v1.2.8\\">v1.2.8</a> - 2023-02-09</h2>\\n<h3>Merged</h3>\\n<ul>\\n<li>[Fix] Fix long option followed by single dash <a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/pull/17\\"><code>[#17](https://github.com/minimistjs/minimist/issues/17)</code></a></li>\\n<li>[Tests] Remove duplicate test <a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/pull/12\\"><code>[#12](https://github.com/minimistjs/minimist/issues/12)</code></a></li>\\n<li>[Fix] opt.string works with multiple aliases <a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/pull/10\\"><code>[#10](https://github.com/minimistjs/minimist/issues/10)</code></a></li>\\n</ul>\\n<h3>Fixed</h3>\\n<ul>\\n<li>[Fix] Fix long option followed by single dash (<a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/issues/17\\">#17</a>) <a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/issues/15\\"><code>[#15](https://github.com/minimistjs/minimist/issues/15)</code></a></li>\\n<li>[Tests] Remove duplicate test (<a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/issues/12\\">#12</a>) <a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/issues/8\\"><code>[#8](https://github.com/minimistjs/minimist/issues/8)</code></a></li>\\n<li>[Fix] Fix long option followed by single dash <a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/issues/15\\"><code>[#15](https://github.com/minimistjs/minimist/issues/15)</code></a></li>\\n<li>[Fix] opt.string works with multiple aliases (<a href=\\"https://github-redirect.dependabot.com/minimistjs/minimist/issues/10\\">#10</a>) <a hre ...

# %% [markdown]
# If we're dealing with JSON data, use...you guessed it!  The .json() method (note: This will raise an exception if you're not dealing with JSON data/the JSON decoding fails)

# %%
r.json()
# Out:
# [{'id': '27538980347',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 253501538,
#    'name': 'EricRicketts/Exercism',
#    'url': 'https://api.github.com/repos/EricRicketts/Exercism'},
#   'payload': {'action': 'opened',
#    'number': 59,
#    'pull_request': {'url': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/59',
#     'id': 1265729561,
#     'node_id': 'PR_kwDODxwgYs5LcYAZ',
#     'html_url': 'https://github.com/EricRicketts/Exercism/pull/59',
#     'diff_url': 'https://github.com/EricRicketts/Exercism/pull/59.diff',
#     'patch_url': 'https://github.com/EricRicketts/Exercism/pull/59.patch',
#     'issue_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues/59',
#     'number': 59,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump minimist from 1.2.5 to 1.2.8 in /javascript/annalyns-infiltration',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [minimist](https://github.com/minimistjs/minimist) from 1.2.5 to 1.2.8.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/minimistjs/minimist/blob/main/CHANGELOG.md">minimist\'s changelog</a>.</em></p>\n<blockquote>\n<h2><a href="https://github.com/minimistjs/minimist/compare/v1.2.7...v1.2.8">v1.2.8</a> - 2023-02-09</h2>\n<h3>Merged</h3>\n<ul>\n<li>[Fix] Fix long option followed by single dash <a href="https://github-redirect.dependabot.com/minimistjs/minimist/pull/17"><code>[#17](https://github.com/minimistjs/minimist/issues/17)</code></a></li>\n<li>[Tests] Remove duplicate test <a href="https://github-redirect.dependabot.com/minimistjs/minimist/pull/12"><code>[#12](https://github.com/minimistjs/minimist/issues/12)</code></a></li>\n<li>[Fix] opt.string works with multiple aliases <a href="https://github-redirect.dependabot.com/minimistjs/minimist/pull/10"><code>[#10](https://github.com/minimistjs/minimist/issues/10)</code></a></li>\n</ul>\n<h3>Fixed</h3>\n<ul>\n<li>[Fix] Fix long option followed by single dash (<a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/17">#17</a>) <a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/15"><code>[#15](https://github.com/minimistjs/minimist/issues/15)</code></a></li>\n<li>[Tests] Remove duplicate test (<a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/12">#12</a>) <a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/8"><code>[#8](https://github.com/minimistjs/minimist/issues/8)</code></a></li>\n<li>[Fix] Fix long option followed by single dash <a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/15"><code>[#15](https://github.com/minimistjs/minimist/issues/15)</code></a></li>\n<li>[Fix] opt.string works with multiple aliases (<a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/10">#10</a>) <a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/9"><code>[#9](https://github.com/minimistjs/minimist/issues/9)</code></a></li>\n<li>[Fix] Fix handling of short option with non-trivial equals <a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/5"><code>[#5](https://github.com/minimistjs/minimist/issues/5)</code></a></li>\n<li>[Tests] Remove duplicate test <a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/8"><code>[#8](https://github.com/minimistjs/minimist/issues/8)</code></a></li>\n<li>[Fix] opt.string works with multiple aliases <a href="https://github-redirect.dependabot.com/minimistjs/minimist/issues/9"><code>[#9](https://github.com/minimistjs/minimist/issues/9)</code></a></li>\n</ul>\n<h3>Commits</h3>\n<ul>\n<li>Merge tag \'v0.2.3\' <a href="https://github.com/minimistjs/minimist/commit/a0267947c7870fc5847cf2d437fbe33f392767da"><code>a026794</code></a></li>\n<li>[eslint] fix indentation and whitespace <a href="https://github.com/minimistjs/minimist/commit/5368ca4147e974138a54cc0dc4cea8f756546b70"><code>5368ca4</code></a></li>\n<li>[eslint] fix indentation and whitespace <a href="https://github.com/minimistjs/minimist/commit/e5f5067259ceeaf0b098d14bec910f87e58708c7"><code>e5f5067</code></a></li>\n<li>[eslint] more cleanup <a href="https://github.com/minimistjs/minimist/commit/62fde7d935f83417fb046741531a9e2346a36976"><code>62fde7d</code></a></li>\n<li>[eslint] more cleanup <a href="https://github.com/minimistjs/minimist/commit/36ac5d0d95e4947d074e5737d94814034ca335d1"><code>36ac5d0</code></a></li>\n<li>[meta] add <code>auto-changelog</code> <a href="https://github.com/minimistjs/minimist/commit/73923d223553fca08b1ba77e3fbc2a492862ae4c"><code>73923d2</code></a></li>\n<li>[actions] add reusable workflows <a href="https://github.com/minimistjs/minimist/commit/d80727df77bfa9e631044d7f16368d8f09242c91"><code>d80727d</code></a></li>\n<li>[eslint] add eslint; rules to enable later are warnings <a href="https://github.com/minimistjs/minimi ...
#     'created_at': '2023-03-07T06:57:42Z',
#     'updated_at': '2023-03-07T06:57:42Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/59/commits',
#     'review_comments_url': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/59/comments',
#     'review_comment_url': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues/59/comments',
#     'statuses_url': 'https://api.github.com/repos/EricRicketts/Exercism/statuses/03b5c0dafb63eb174b82a58d28533df0618c0867',
#     'head': {'label': 'EricRicketts:dependabot/npm_and_yarn/javascript/annalyns-infiltration/minimist-1.2.8',
#      'ref': 'dependabot/npm_and_yarn/javascript/annalyns-infiltration/minimist-1.2.8',
#      'sha': '03b5c0dafb63eb174b82a58d28533df0618c0867',
#      'user': {'login': 'EricRicketts',
#       'id': 5551943,
#       'node_id': 'MDQ6VXNlcjU1NTE5NDM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5551943?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/EricRicketts',
#       'html_url': 'https://github.com/EricRicketts',
#       'followers_url': 'https://api.github.com/users/EricRicketts/followers',
#       'following_url': 'https://api.github.com/users/EricRicketts/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/EricRicketts/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/EricRicketts/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/EricRicketts/subscriptions',
#       'organizations_url': 'https://api.github.com/users/EricRicketts/orgs',
#       'repos_url': 'https://api.github.com/users/EricRicketts/repos',
#       'events_url': 'https://api.github.com/users/EricRicketts/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/EricRicketts/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 253501538,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNTM1MDE1Mzg=',
#       'name': 'Exercism',
#       'full_name': 'EricRicketts/Exercism',
#       'private': False,
#       'owner': {'login': 'EricRicketts',
#        'id': 5551943,
#        'node_id': 'MDQ6VXNlcjU1NTE5NDM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5551943?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/EricRicketts',
#        'html_url': 'https://github.com/EricRicketts',
#        'followers_url': 'https://api.github.com/users/EricRicketts/followers',
#        'following_url': 'https://api.github.com/users/EricRicketts/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/EricRicketts/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/EricRicketts/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/EricRicketts/subscriptions',
#        'organizations_url': 'https://api.github.com/users/EricRicketts/orgs',
#        'repos_url': 'https://api.github.com/users/EricRicketts/repos',
#        'events_url': 'https://api.github.com/users/EricRicketts/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/EricRicketts/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/EricRicketts/Exercism',
#       'description': 'exercises from exercism.io website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/EricRicketts/Exercism',
#       'forks_url': 'https://api.github.com/repos/EricRicketts/Exercism/forks',
#       'keys_url': 'https://api.github.com/repos/EricRicketts/Exercism/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/EricRicketts/Exercism/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/EricRicketts/Exercism/teams',
#       'hooks_url': 'https://api.github.com/repos/EricRicketts/Exercism/hooks',
#       'issue_events_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/EricRicketts/Exercism/events',
#       'assignees_url': 'https://api.github.com/repos/EricRicketts/Exercism/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/EricRicketts/Exercism/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/EricRicketts/Exercism/tags',
#       'blobs_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/EricRicketts/Exercism/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/EricRicketts/Exercism/languages',
#       'stargazers_url': 'https://api.github.com/repos/EricRicketts/Exercism/stargazers',
#       'contributors_url': 'https://api.github.com/repos/EricRicketts/Exercism/contributors',
#       'subscribers_url': 'https://api.github.com/repos/EricRicketts/Exercism/subscribers',
#       'subscription_url': 'https://api.github.com/repos/EricRicketts/Exercism/subscription',
#       'commits_url': 'https://api.github.com/repos/EricRicketts/Exercism/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/EricRicketts/Exercism/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/EricRicketts/Exercism/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/EricRicketts/Exercism/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/EricRicketts/Exercism/merges',
#       'archive_url': 'https://api.github.com/repos/EricRicketts/Exercism/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/EricRicketts/Exercism/downloads',
#       'issues_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/EricRicketts/Exercism/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/EricRicketts/Exercism/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/EricRicketts/Exercism/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/EricRicketts/Exercism/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/EricRicketts/Exercism/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/EricRicketts/Exercism/deployments',
#       'created_at': '2020-04-06T13:11:12Z',
#       'updated_at': '2022-02-08T17:08:09Z',
#       'pushed_at': '2023-03-07T06:57:43Z',
#       'git_url': 'git://github.com/EricRicketts/Exercism.git',
#       'ssh_url': 'git@github.com:EricRicketts/Exercism.git',
#       'clone_url': 'https://github.com/EricRicketts/Exercism.git',
#       'svn_url': 'https://github.com/EricRicketts/Exercism',
#       'homepage': None,
#       'size': 5508,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 56,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 56,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'EricRicketts:master',
#      'ref': 'master',
#      'sha': '0bd58a9d31e34530bd7ad54b109641e44fab1164',
#      'user': {'login': 'EricRicketts',
#       'id': 5551943,
#       'node_id': 'MDQ6VXNlcjU1NTE5NDM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5551943?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/EricRicketts',
#       'html_url': 'https://github.com/EricRicketts',
#       'followers_url': 'https://api.github.com/users/EricRicketts/followers',
#       'following_url': 'https://api.github.com/users/EricRicketts/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/EricRicketts/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/EricRicketts/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/EricRicketts/subscriptions',
#       'organizations_url': 'https://api.github.com/users/EricRicketts/orgs',
#       'repos_url': 'https://api.github.com/users/EricRicketts/repos',
#       'events_url': 'https://api.github.com/users/EricRicketts/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/EricRicketts/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 253501538,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNTM1MDE1Mzg=',
#       'name': 'Exercism',
#       'full_name': 'EricRicketts/Exercism',
#       'private': False,
#       'owner': {'login': 'EricRicketts',
#        'id': 5551943,
#        'node_id': 'MDQ6VXNlcjU1NTE5NDM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/5551943?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/EricRicketts',
#        'html_url': 'https://github.com/EricRicketts',
#        'followers_url': 'https://api.github.com/users/EricRicketts/followers',
#        'following_url': 'https://api.github.com/users/EricRicketts/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/EricRicketts/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/EricRicketts/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/EricRicketts/subscriptions',
#        'organizations_url': 'https://api.github.com/users/EricRicketts/orgs',
#        'repos_url': 'https://api.github.com/users/EricRicketts/repos',
#        'events_url': 'https://api.github.com/users/EricRicketts/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/EricRicketts/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/EricRicketts/Exercism',
#       'description': 'exercises from exercism.io website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/EricRicketts/Exercism',
#       'forks_url': 'https://api.github.com/repos/EricRicketts/Exercism/forks',
#       'keys_url': 'https://api.github.com/repos/EricRicketts/Exercism/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/EricRicketts/Exercism/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/EricRicketts/Exercism/teams',
#       'hooks_url': 'https://api.github.com/repos/EricRicketts/Exercism/hooks',
#       'issue_events_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/EricRicketts/Exercism/events',
#       'assignees_url': 'https://api.github.com/repos/EricRicketts/Exercism/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/EricRicketts/Exercism/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/EricRicketts/Exercism/tags',
#       'blobs_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/EricRicketts/Exercism/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/EricRicketts/Exercism/languages',
#       'stargazers_url': 'https://api.github.com/repos/EricRicketts/Exercism/stargazers',
#       'contributors_url': 'https://api.github.com/repos/EricRicketts/Exercism/contributors',
#       'subscribers_url': 'https://api.github.com/repos/EricRicketts/Exercism/subscribers',
#       'subscription_url': 'https://api.github.com/repos/EricRicketts/Exercism/subscription',
#       'commits_url': 'https://api.github.com/repos/EricRicketts/Exercism/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/EricRicketts/Exercism/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/EricRicketts/Exercism/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/EricRicketts/Exercism/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/EricRicketts/Exercism/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/EricRicketts/Exercism/merges',
#       'archive_url': 'https://api.github.com/repos/EricRicketts/Exercism/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/EricRicketts/Exercism/downloads',
#       'issues_url': 'https://api.github.com/repos/EricRicketts/Exercism/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/EricRicketts/Exercism/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/EricRicketts/Exercism/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/EricRicketts/Exercism/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/EricRicketts/Exercism/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/EricRicketts/Exercism/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/EricRicketts/Exercism/deployments',
#       'created_at': '2020-04-06T13:11:12Z',
#       'updated_at': '2022-02-08T17:08:09Z',
#       'pushed_at': '2023-03-07T06:57:43Z',
#       'git_url': 'git://github.com/EricRicketts/Exercism.git',
#       'ssh_url': 'git@github.com:EricRicketts/Exercism.git',
#       'clone_url': 'https://github.com/EricRicketts/Exercism.git',
#       'svn_url': 'https://github.com/EricRicketts/Exercism',
#       'homepage': None,
#       'size': 5508,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 56,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 56,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/59'},
#      'html': {'href': 'https://github.com/EricRicketts/Exercism/pull/59'},
#      'issue': {'href': 'https://api.github.com/repos/EricRicketts/Exercism/issues/59'},
#      'comments': {'href': 'https://api.github.com/repos/EricRicketts/Exercism/issues/59/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/59/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/EricRicketts/Exercism/pulls/59/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/EricRicketts/Exercism/statuses/03b5c0dafb63eb174b82a58d28533df0618c0867'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 10,
#     'deletions': 7,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980429',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 346652840,
#    'name': 'home-assistant/os-agent',
#    'url': 'https://api.github.com/repos/home-assistant/os-agent'},
#   'payload': {'ref': 'dependabot/go_modules/github.com/getsentry/sentry-go-0.19.0',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Daemon allowing to control OS features through D-Bus',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z',
#   'org': {'id': 13844975,
#    'login': 'home-assistant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/home-assistant',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13844975?'}},
#  {'id': '27538980419',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 328672863,
#    'name': 'KnodesCommunity/nest-casl',
#    'url': 'https://api.github.com/repos/KnodesCommunity/nest-casl'},
#   'payload': {'ref': 'renovate/knodes-eslint-config-1.x-lockfile',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z',
#   'org': {'id': 63706334,
#    'login': 'KnodesCommunity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/KnodesCommunity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63706334?'}},
#  {'id': '27538980293',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 324167642,
#    'name': 'cityssm/lighthouse-scans',
#    'url': 'https://api.github.com/repos/cityssm/lighthouse-scans'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/typescript-eslint/parser-5.54.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z',
#   'org': {'id': 34131810,
#    'login': 'cityssm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cityssm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34131810?'}},
#  {'id': '27538980396',
#   'type': 'PushEvent',
#   'actor': {'id': 60980455,
#    'login': 'vikaskushwahaa',
#    'display_login': 'vikaskushwahaa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vikaskushwahaa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60980455?'},
#   'repo': {'id': 585065258,
#    'name': 'ProjectSmashers/job-portal-backend',
#    'url': 'https://api.github.com/repos/ProjectSmashers/job-portal-backend'},
#   'payload': {'repository_id': 585065258,
#    'push_id': 12850437741,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/vik-11',
#    'head': '53ea194f4334ac1b72b28035961a8e06bd91c61a',
#    'before': 'f6686a1bbc5a553dd623653cdcff9eac83ca6750',
#    'commits': [{'sha': '53ea194f4334ac1b72b28035961a8e06bd91c61a',
#      'author': {'email': 'vikaskushwaha40@gmail.com',
#       'name': 'Vikas Kushwaha'},
#      'message': 'company auth added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ProjectSmashers/job-portal-backend/commits/53ea194f4334ac1b72b28035961a8e06bd91c61a'}]},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980423',
#   'type': 'PushEvent',
#   'actor': {'id': 14960087,
#    'login': 'Naandalist',
#    'display_login': 'Naandalist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Naandalist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14960087?'},
#   'repo': {'id': 545596753,
#    'name': 'Naandalist/github-activity',
#    'url': 'https://api.github.com/repos/Naandalist/github-activity'},
#   'payload': {'repository_id': 545596753,
#    'push_id': 12850437736,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0c1ae6b825162c6e9adaa0444dd8f164ec254ac5',
#    'before': '025511aa12d048b475d93e6f34bf0b89a412c6a4',
#    'commits': [{'sha': '0c1ae6b825162c6e9adaa0444dd8f164ec254ac5',
#      'author': {'email': 'listiananda.apriliawan@gmail.com',
#       'name': '“naandalist”'},
#      'message': 'Activity on 2023-03-07 13:57:41 :four_leaf_clover:',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Naandalist/github-activity/commits/0c1ae6b825162c6e9adaa0444dd8f164ec254ac5'}]},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980292',
#   'type': 'WatchEvent',
#   'actor': {'id': 54048747,
#    'login': 'Good4lien',
#    'display_login': 'Good4lien',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Good4lien',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54048747?'},
#   'repo': {'id': 461701104,
#    'name': 'jaynepatt/terminal',
#    'url': 'https://api.github.com/repos/jaynepatt/terminal'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980406',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 189470531,
#    'name': 'hober/bikeshed',
#    'url': 'https://api.github.com/repos/hober/bikeshed'},
#   'payload': {'ref': 'dependabot/pip/pylint-2.16.3',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980380',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 268111021,
#    'name': 'PureUsername/pull',
#    'url': 'https://api.github.com/repos/PureUsername/pull'},
#   'payload': {'action': 'closed',
#    'number': 206,
#    'pull_request': {'url': 'https://api.github.com/repos/PureUsername/pull/pulls/206',
#     'id': 1243217801,
#     'node_id': 'PR_kwDOD_sMrc5KGf-J',
#     'html_url': 'https://github.com/PureUsername/pull/pull/206',
#     'diff_url': 'https://github.com/PureUsername/pull/pull/206.diff',
#     'patch_url': 'https://github.com/PureUsername/pull/pull/206.patch',
#     'issue_url': 'https://api.github.com/repos/PureUsername/pull/issues/206',
#     'number': 206,
#     'state': 'closed',
#     'locked': False,
#     'title': '⬆️ Bump jest from 27.4.7 to 29.4.3',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [jest](https://github.com/facebook/jest/tree/HEAD/packages/jest) from 27.4.7 to 29.4.3.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/facebook/jest/releases">jest\'s releases</a>.</em></p>\n<blockquote>\n<h2>v29.4.3</h2>\n<h2>Features</h2>\n<ul>\n<li><code>[expect]</code> Update <code>toThrow()</code> to be able to use error <code>cause</code>s (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13606">#13606</a>)</li>\n<li><code>[jest-core]</code> allow to use <code>workerIdleMemoryLimit</code> with only 1 worker or <code>runInBand</code> option (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13846">#13846</a>)</li>\n<li><code>[jest-message-util]</code> Add support for <a href="https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Error/cause">error <code>cause</code>s</a> (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13868">#13868</a> &amp; <a href="https://github-redirect.dependabot.com/facebook/jest/pull/13912">#13912</a>)</li>\n<li><code>[jest-runtime]</code> Revert <code>import assertions</code> for JSON modules as it\'s been relegated to Stage 2 (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13911">#13911</a>)</li>\n</ul>\n<h2>Fixes</h2>\n<ul>\n<li><code>[@jest/expect-utils]</code> <code>subsetEquality</code> should consider also an object\'s inherited string keys (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13824">#13824</a>)</li>\n<li><code>[jest-mock]</code> Clear mock state when <code>jest.restoreAllMocks()</code> is called (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13867">#13867</a>)</li>\n<li><code>[jest-mock]</code> Prevent <code>mockImplementationOnce</code> and <code>mockReturnValueOnce</code> bleeding into <code>withImplementation</code> (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13888">#13888</a>)</li>\n<li><code>[jest-mock]</code> Do not restore mocks when <code>jest.resetAllMocks()</code> is called (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13866">#13866</a>)</li>\n</ul>\n<h2>New Contributors</h2>\n<ul>\n<li><a href="https://github.com/brodo"><code>@\u200bbrodo</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/facebook/jest/pull/13868">facebook/jest#13868</a></li>\n<li><a href="https://github.com/DannyNemer"><code>@\u200bDannyNemer</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/facebook/jest/pull/13878">facebook/jest#13878</a></li>\n<li><a href="https://github.com/ghusse"><code>@\u200bghusse</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/facebook/jest/pull/13846">facebook/jest#13846</a></li>\n<li><a href="https://github.com/broofa"><code>@\u200bbroofa</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/facebook/jest/pull/13911">facebook/jest#13911</a></li>\n</ul>\n<p><strong>Full Changelog</strong>: <a href="https://github.com/facebook/jest/compare/v29.4.2...v29.4.3">https://github.com/facebook/jest/compare/v29.4.2...v29.4.3</a></p>\n<h2>v29.4.2</h2>\n<h2>Features</h2>\n<ul>\n<li><code>[@jest/core]</code> Instrument significant lifecycle events with <a href="https://nodejs.org/docs/latest-v16.x/api/perf_hooks.html#performancemarkname-options"><code>performance.mark()</code></a> (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13859">#13859</a>)</li>\n</ul>\n<h2>Fixes</h2>\n<ul>\n<li><code>[expect, @jest/expect]</code> Provide type of <code>actual</code> as a generic argument to <code>Matchers</code> to allow better-typed extensions (<a href="https://github-redirect.dependabot.com/facebook/jest/pull/13848">#13848</a>)</li>\n<li><code>[jest-circus]</code> Added explicit mention of test failing because <code>done()</code> is not being called in error messag ...
#     'created_at': '2023-02-16T06:57:53Z',
#     'updated_at': '2023-03-07T06:57:42Z',
#     'closed_at': '2023-03-07T06:57:42Z',
#     'merged_at': None,
#     'merge_commit_sha': '22b89e088d775890e4f13a09d6c74a00fa5b2ac1',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2290933214,
#       'node_id': 'MDU6TGFiZWwyMjkwOTMzMjE0',
#       'url': 'https://api.github.com/repos/PureUsername/pull/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/PureUsername/pull/pulls/206/commits',
#     'review_comments_url': 'https://api.github.com/repos/PureUsername/pull/pulls/206/comments',
#     'review_comment_url': 'https://api.github.com/repos/PureUsername/pull/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/PureUsername/pull/issues/206/comments',
#     'statuses_url': 'https://api.github.com/repos/PureUsername/pull/statuses/52f417562e5a8119eccce4ea979a79e578f0f4ee',
#     'head': {'label': 'PureUsername:dependabot/npm_and_yarn/jest-29.4.3',
#      'ref': 'dependabot/npm_and_yarn/jest-29.4.3',
#      'sha': '52f417562e5a8119eccce4ea979a79e578f0f4ee',
#      'user': {'login': 'PureUsername',
#       'id': 60883071,
#       'node_id': 'MDQ6VXNlcjYwODgzMDcx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/60883071?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/PureUsername',
#       'html_url': 'https://github.com/PureUsername',
#       'followers_url': 'https://api.github.com/users/PureUsername/followers',
#       'following_url': 'https://api.github.com/users/PureUsername/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/PureUsername/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/PureUsername/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/PureUsername/subscriptions',
#       'organizations_url': 'https://api.github.com/users/PureUsername/orgs',
#       'repos_url': 'https://api.github.com/users/PureUsername/repos',
#       'events_url': 'https://api.github.com/users/PureUsername/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/PureUsername/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 268111021,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjgxMTEwMjE=',
#       'name': 'pull',
#       'full_name': 'PureUsername/pull',
#       'private': False,
#       'owner': {'login': 'PureUsername',
#        'id': 60883071,
#        'node_id': 'MDQ6VXNlcjYwODgzMDcx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/60883071?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/PureUsername',
#        'html_url': 'https://github.com/PureUsername',
#        'followers_url': 'https://api.github.com/users/PureUsername/followers',
#        'following_url': 'https://api.github.com/users/PureUsername/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/PureUsername/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/PureUsername/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/PureUsername/subscriptions',
#        'organizations_url': 'https://api.github.com/users/PureUsername/orgs',
#        'repos_url': 'https://api.github.com/users/PureUsername/repos',
#        'events_url': 'https://api.github.com/users/PureUsername/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/PureUsername/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/PureUsername/pull',
#       'description': '⬇️ Keep your forks up-to-date via automated PRs',
#       'fork': True,
#       'url': 'https://api.github.com/repos/PureUsername/pull',
#       'forks_url': 'https://api.github.com/repos/PureUsername/pull/forks',
#       'keys_url': 'https://api.github.com/repos/PureUsername/pull/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/PureUsername/pull/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/PureUsername/pull/teams',
#       'hooks_url': 'https://api.github.com/repos/PureUsername/pull/hooks',
#       'issue_events_url': 'https://api.github.com/repos/PureUsername/pull/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/PureUsername/pull/events',
#       'assignees_url': 'https://api.github.com/repos/PureUsername/pull/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/PureUsername/pull/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/PureUsername/pull/tags',
#       'blobs_url': 'https://api.github.com/repos/PureUsername/pull/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/PureUsername/pull/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/PureUsername/pull/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/PureUsername/pull/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/PureUsername/pull/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/PureUsername/pull/languages',
#       'stargazers_url': 'https://api.github.com/repos/PureUsername/pull/stargazers',
#       'contributors_url': 'https://api.github.com/repos/PureUsername/pull/contributors',
#       'subscribers_url': 'https://api.github.com/repos/PureUsername/pull/subscribers',
#       'subscription_url': 'https://api.github.com/repos/PureUsername/pull/subscription',
#       'commits_url': 'https://api.github.com/repos/PureUsername/pull/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/PureUsername/pull/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/PureUsername/pull/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/PureUsername/pull/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/PureUsername/pull/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/PureUsername/pull/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/PureUsername/pull/merges',
#       'archive_url': 'https://api.github.com/repos/PureUsername/pull/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/PureUsername/pull/downloads',
#       'issues_url': 'https://api.github.com/repos/PureUsername/pull/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/PureUsername/pull/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/PureUsername/pull/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/PureUsername/pull/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/PureUsername/pull/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/PureUsername/pull/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/PureUsername/pull/deployments',
#       'created_at': '2020-05-30T15:49:29Z',
#       'updated_at': '2022-01-08T04:55:14Z',
#       'pushed_at': '2023-03-07T06:57:39Z',
#       'git_url': 'git://github.com/PureUsername/pull.git',
#       'ssh_url': 'git@github.com:PureUsername/pull.git',
#       'clone_url': 'https://github.com/PureUsername/pull.git',
#       'svn_url': 'https://github.com/PureUsername/pull',
#       'homepage': 'https://github.com/apps/pull',
#       'size': 4651,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 6,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'PureUsername:master',
#      'ref': 'master',
#      'sha': '3594eef48ef16b53fffaca1c64dfc173f798caf1',
#      'user': {'login': 'PureUsername',
#       'id': 60883071,
#       'node_id': 'MDQ6VXNlcjYwODgzMDcx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/60883071?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/PureUsername',
#       'html_url': 'https://github.com/PureUsername',
#       'followers_url': 'https://api.github.com/users/PureUsername/followers',
#       'following_url': 'https://api.github.com/users/PureUsername/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/PureUsername/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/PureUsername/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/PureUsername/subscriptions',
#       'organizations_url': 'https://api.github.com/users/PureUsername/orgs',
#       'repos_url': 'https://api.github.com/users/PureUsername/repos',
#       'events_url': 'https://api.github.com/users/PureUsername/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/PureUsername/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 268111021,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjgxMTEwMjE=',
#       'name': 'pull',
#       'full_name': 'PureUsername/pull',
#       'private': False,
#       'owner': {'login': 'PureUsername',
#        'id': 60883071,
#        'node_id': 'MDQ6VXNlcjYwODgzMDcx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/60883071?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/PureUsername',
#        'html_url': 'https://github.com/PureUsername',
#        'followers_url': 'https://api.github.com/users/PureUsername/followers',
#        'following_url': 'https://api.github.com/users/PureUsername/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/PureUsername/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/PureUsername/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/PureUsername/subscriptions',
#        'organizations_url': 'https://api.github.com/users/PureUsername/orgs',
#        'repos_url': 'https://api.github.com/users/PureUsername/repos',
#        'events_url': 'https://api.github.com/users/PureUsername/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/PureUsername/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/PureUsername/pull',
#       'description': '⬇️ Keep your forks up-to-date via automated PRs',
#       'fork': True,
#       'url': 'https://api.github.com/repos/PureUsername/pull',
#       'forks_url': 'https://api.github.com/repos/PureUsername/pull/forks',
#       'keys_url': 'https://api.github.com/repos/PureUsername/pull/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/PureUsername/pull/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/PureUsername/pull/teams',
#       'hooks_url': 'https://api.github.com/repos/PureUsername/pull/hooks',
#       'issue_events_url': 'https://api.github.com/repos/PureUsername/pull/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/PureUsername/pull/events',
#       'assignees_url': 'https://api.github.com/repos/PureUsername/pull/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/PureUsername/pull/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/PureUsername/pull/tags',
#       'blobs_url': 'https://api.github.com/repos/PureUsername/pull/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/PureUsername/pull/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/PureUsername/pull/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/PureUsername/pull/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/PureUsername/pull/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/PureUsername/pull/languages',
#       'stargazers_url': 'https://api.github.com/repos/PureUsername/pull/stargazers',
#       'contributors_url': 'https://api.github.com/repos/PureUsername/pull/contributors',
#       'subscribers_url': 'https://api.github.com/repos/PureUsername/pull/subscribers',
#       'subscription_url': 'https://api.github.com/repos/PureUsername/pull/subscription',
#       'commits_url': 'https://api.github.com/repos/PureUsername/pull/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/PureUsername/pull/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/PureUsername/pull/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/PureUsername/pull/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/PureUsername/pull/contents/{+path}',
# ...
#    'name': 'germanstandvurder/germanstandvurder',
#    'url': 'https://api.github.com/repos/germanstandvurder/germanstandvurder'},
#   'payload': {'repository_id': 365182270,
#    'push_id': 12850437675,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7c6f726e836f609e36473b08cc5728b8bd1785de',
#    'before': '19d09d88c1f4c77ca198a468a6e4602039dfe077',
#    'commits': [{'sha': '7c6f726e836f609e36473b08cc5728b8bd1785de',
#      'author': {'email': 'germanstandvurder@users.noreply.github.com',
#       'name': 'germanstandvurder'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/germanstandvurder/germanstandvurder/commits/7c6f726e836f609e36473b08cc5728b8bd1785de'}]},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980302',
#   'type': 'PushEvent',
#   'actor': {'id': 104337520,
#    'login': 'JasonTheH3cker',
#    'display_login': 'JasonTheH3cker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JasonTheH3cker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104337520?'},
#   'repo': {'id': 597214603,
#    'name': 'JasonTheH3cker/socket_programming',
#    'url': 'https://api.github.com/repos/JasonTheH3cker/socket_programming'},
#   'payload': {'repository_id': 597214603,
#    'push_id': 12850437680,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aa15b27cfe8170e12ef6672ad4f0b1278e0cf90a',
#    'before': '261d338832593e433167e393c88d2cd403e1800b',
#    'commits': [{'sha': 'aa15b27cfe8170e12ef6672ad4f0b1278e0cf90a',
#      'author': {'email': 'zhang.haozhe1@northeastern.edu',
#       'name': 'HaozheZhang0818'},
#      'message': 'Hard coded authentication implemented, database implementation in process',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JasonTheH3cker/socket_programming/commits/aa15b27cfe8170e12ef6672ad4f0b1278e0cf90a'}]},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980220',
#   'type': 'CreateEvent',
#   'actor': {'id': 125791198,
#    'login': 'sathishcyberintelsysnew',
#    'display_login': 'sathishcyberintelsysnew',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sathishcyberintelsysnew',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125791198?'},
#   'repo': {'id': 604557864,
#    'name': 'sathishcyberintelsysnew/vulhub',
#    'url': 'https://api.github.com/repos/sathishcyberintelsysnew/vulhub'},
#   'payload': {'ref': 'snyk-fix-50a0360c44638598b988b734ed9edc1e',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Pre-Built Vulnerable Environments Based on Docker-Compose',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980298',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 327714440,
#    'name': 'TeoZosa/cookiecutter-cruft-poetry-tox-pre-commit-ci-cd-instance',
#    'url': 'https://api.github.com/repos/TeoZosa/cookiecutter-cruft-poetry-tox-pre-commit-ci-cd-instance'},
#   'payload': {'repository_id': 327714440,
#    'push_id': 12850437678,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '18edfd982b6370220ff75a30f698955ab833bc68',
#    'before': '07d5a618a89dcbd8321d3a82d6d0e2ae5e244b5f',
#    'commits': [{'sha': '18edfd982b6370220ff75a30f698955ab833bc68',
#      'author': {'email': 'github@users.noreply.github.com',
#       'name': 'github-action-benchmark'},
#      'message': 'add Benchmark (pytest) benchmark result for be0858ad805b32de50def59e77bb39a9dd592783',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TeoZosa/cookiecutter-cruft-poetry-tox-pre-commit-ci-cd-instance/commits/18edfd982b6370220ff75a30f698955ab833bc68'}]},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z'},
#  {'id': '27538980289',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 97195285,
#    'login': 'webkit-early-warning-system',
#    'display_login': 'webkit-early-warning-system',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/webkit-early-warning-system',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97195285?'},
#   'repo': {'id': 320636477,
#    'name': 'WebKit/WebKit',
#    'url': 'https://api.github.com/repos/WebKit/WebKit'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/WebKit/WebKit/issues/11156',
#     'repository_url': 'https://api.github.com/repos/WebKit/WebKit',
#     'labels_url': 'https://api.github.com/repos/WebKit/WebKit/issues/11156/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/WebKit/WebKit/issues/11156/comments',
#     'events_url': 'https://api.github.com/repos/WebKit/WebKit/issues/11156/events',
#     'html_url': 'https://github.com/WebKit/WebKit/pull/11156',
#     'id': 1612834299,
#     'node_id': 'PR_kwDOExyGPc5LcW2l',
#     'number': 11156,
#     'title': 'TestWebKitAPI.WebKit.ScrollPinningBehaviors fails when GPU Process and UI side compositing are enabled',
#     'user': {'login': 'rniwa',
#      'id': 285965,
#      'node_id': 'MDQ6VXNlcjI4NTk2NQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/285965?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rniwa',
#      'html_url': 'https://github.com/rniwa',
#      'followers_url': 'https://api.github.com/users/rniwa/followers',
#      'following_url': 'https://api.github.com/users/rniwa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rniwa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rniwa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rniwa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rniwa/orgs',
#      'repos_url': 'https://api.github.com/users/rniwa/repos',
#      'events_url': 'https://api.github.com/users/rniwa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rniwa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 3939231851,
#       'node_id': 'LA_kwDOExyGPc7qy-hr',
#       'url': 'https://api.github.com/repos/WebKit/WebKit/labels/Tools%20/%20Tests',
#       'name': 'Tools / Tests',
#       'color': 'FFFFFF',
#       'default': False,
#       'description': 'Tools in the Tools directory, build issues, test infrastructure, and bugs in test cases'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'rniwa',
#      'id': 285965,
#      'node_id': 'MDQ6VXNlcjI4NTk2NQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/285965?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rniwa',
#      'html_url': 'https://github.com/rniwa',
#      'followers_url': 'https://api.github.com/users/rniwa/followers',
#      'following_url': 'https://api.github.com/users/rniwa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rniwa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rniwa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rniwa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rniwa/orgs',
#      'repos_url': 'https://api.github.com/users/rniwa/repos',
#      'events_url': 'https://api.github.com/users/rniwa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rniwa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'rniwa',
#       'id': 285965,
#       'node_id': 'MDQ6VXNlcjI4NTk2NQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/285965?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rniwa',
#       'html_url': 'https://github.com/rniwa',
#       'followers_url': 'https://api.github.com/users/rniwa/followers',
#       'following_url': 'https://api.github.com/users/rniwa/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rniwa/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rniwa/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rniwa/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rniwa/orgs',
#       'repos_url': 'https://api.github.com/users/rniwa/repos',
#       'events_url': 'https://api.github.com/users/rniwa/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rniwa/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2023-03-07T06:52:53Z',
#     'updated_at': '2023-03-07T06:57:43Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/WebKit/WebKit/pulls/11156',
#      'html_url': 'https://github.com/WebKit/WebKit/pull/11156',
#      'diff_url': 'https://github.com/WebKit/WebKit/pull/11156.diff',
#      'patch_url': 'https://github.com/WebKit/WebKit/pull/11156.patch',
#      'merged_at': None},
#     'body': '#### 876db80e47039868cb7e80f55171e1bad21c61c3\n<pre>\nTestWebKitAPI.WebKit.ScrollPinningBehaviors fails when GPU Process and UI side compositing are enabled\n<a href="https://bugs.webkit.org/show_bug.cgi?id=253486">https://bugs.webkit.org/show_bug.cgi?id=253486</a>\n&lt;rdar://106325154&gt;\n\nReviewed by NOBODY (OOPS!).\n\nThe failure was caused by the test expecting scrolling positions to be updated immediately after setting\nWKPageSetScrollPinningBehavior to kWKScrollPinningBehaviorPinToTop or kWKScrollPinningBehaviorPinToBottom.\n\nDelay the checks until the following presentation update.\n\n* Tools/TestWebKitAPI/TestWebKitAPI.xcodeproj/project.pbxproj:\n* Tools/TestWebKitAPI/Tests/WebKit/ScrollPinningBehaviors.cpp: Removed.\n* Tools/TestWebKitAPI/Tests/WebKit/ScrollPinningBehaviors.mm: Added.\n(WebKit.ScrollPinningBehaviors):\n</pre><!--EWS-Status-Bubble-Start-->\nhttps://github.com/WebKit/WebKit/commit/876db80e47039868cb7e80f55171e1bad21c61c3\n\n| Misc | iOS, tvOS & watchOS  | macOS  | Linux |  Windows |\n| ----- | ---------------------- | ------- |  ----- |  --------- |\n| [![loading](https://user-images.githubusercontent.com/3098702/171232313-daa606f1-8fd6-4b0f-a20b-2cb93c43d19b.png) 🧪 style](https://ews-build.webkit.org/#/builders/6/builds/111265 "Build is in progress. Recent messages:Running worker_preparation") | [⏳ 🛠 ios ](https://ews-build.webkit.org/#/builders/iOS-16-Build-EWS "Waiting in queue, processing has not started yet") | [⏳ 🛠 mac ](https://ews-build.webkit.org/#/builders/macOS-BigSur-Release-Build-EWS "Waiting in queue, processing has not started yet") | [⏳ 🛠 wpe ](https://ews-build.webkit.org/#/builders/WPE-Build-EWS "Waiting in queue, processing has not started yet") | [⏳ 🛠 wincairo ](https://ews-build.webkit.org/#/builders/WinCairo-EWS "Waiting in queue, processing has not started yet") \n| [⏳ 🧪 bindings ](https://ews-build.webkit.org/#/builders/Bindings-Tests-EWS "Waiting in queue, processing has not started yet") | [⏳ 🛠 ios-sim ](https://ews-build.webkit.org/#/builders/iOS-16-Simulator-Build-EWS "Waiting in queue, processing has not started yet") | [⏳ 🛠 mac-AS-debug ](https://ews-build.webkit.org/#/builders/macOS-AppleSilicon-Ventura-Debug-Build-EWS "Waiting in queue, processing has not started yet") | [⏳ 🧪 wpe-wk2 ](https://ews-build.webkit.org/#/builders/WPE-Build-EWS "Waiting in queue, processing has not started yet") | \n| [![loading](https://user-images.githubusercontent.com/3098702/171232313-daa606f1-8fd6-4b0f-a20b-2cb93c43d19b.png) 🧪 webkitperl](https://ews-build.webkit.org/#/builders/19/builds/117028 "Build is in progress. Recent messages:") | [⏳ 🧪 ios-wk2 ](https://ews-build.webkit.org/#/builders/iOS-16-Simulator-Build-EWS "Waiting in queue, processing has not started yet") | [⏳ 🧪 api-mac ](https://ews-build.webkit.org/#/builders/macOS-BigSur-Release-Build-EWS "Waiting in queue, processing has not started yet") | [![loading](https://user-images.githubusercontent.com/3098702/171232313-daa606f1-8fd6-4b0f-a20b-2cb93c43d19b.png) 🛠 gtk](https://ews-build.webkit.org/#/builders/36/builds/103875 "Build is in progress. Recent messages:Running worker_preparation") | \n| [⏳ 🧪 webkitpy ](https://ews-build.webkit.org/#/builders/WebKitPy-Tests-EWS "Waiting in queue, processing has not started yet") | [⏳ 🧪 api-ios ](https://ews-build.webkit.org/#/builders/iOS-16-Simulator-Build-EWS "Waiting in queue, processing has not started yet") | [⏳ 🧪 mac-wk1 ](https://ews-build.webkit.org/#/builders/macOS-BigSur-Release-Build-EWS "Waiting in queue, processing has not started yet") | [![loading](https://user-images.githubusercontent.com/3098702/171232313-daa606f1-8fd6-4b0f-a20b-2cb93c43d19b.png) 🧪 gtk-wk2](https://ews-build.webkit.org/#/builders/36/builds/103875 "Build is in progress. Recent messages:Running worker_preparation") | \n| [![loading](https://user-images.githubusercontent.com/3098702/171232313-daa606f1-8fd6-4b0f-a20b-2cb93c43d19b.png) 🛠 🧪 jsc](https://ews-build.webkit.org/#/builders/1/builds/ ...
#     'reactions': {'url': 'https://api.github.com/repos/WebKit/WebKit/issues/11156/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/WebKit/WebKit/issues/11156/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/WebKit/WebKit/issues/comments/1457641458',
#     'html_url': 'https://github.com/WebKit/WebKit/pull/11156#issuecomment-1457641458',
#     'issue_url': 'https://api.github.com/repos/WebKit/WebKit/issues/11156',
#     'id': 1457641458,
#     'node_id': 'IC_kwDOExyGPc5W4dfy',
#     'user': {'login': 'webkit-early-warning-system',
#      'id': 97195285,
#      'node_id': 'U_kgDOBcsVFQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/97195285?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/webkit-early-warning-system',
#      'html_url': 'https://github.com/webkit-early-warning-system',
#      'followers_url': 'https://api.github.com/users/webkit-early-warning-system/followers',
#      'following_url': 'https://api.github.com/users/webkit-early-warning-system/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/webkit-early-warning-system/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/webkit-early-warning-system/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/webkit-early-warning-system/subscriptions',
#      'organizations_url': 'https://api.github.com/users/webkit-early-warning-system/orgs',
#      'repos_url': 'https://api.github.com/users/webkit-early-warning-system/repos',
#      'events_url': 'https://api.github.com/users/webkit-early-warning-system/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/webkit-early-warning-system/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-03-07T06:57:42Z',
#     'updated_at': '2023-03-07T06:57:42Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'Starting EWS tests for https://github.com/WebKit/WebKit/commit/876db80e47039868cb7e80f55171e1bad21c61c3. Live statuses available at the PR page, https://github.com/WebKit/WebKit/pull/11156',
#     'reactions': {'url': 'https://api.github.com/repos/WebKit/WebKit/issues/comments/1457641458/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-03-07T06:57:43Z',
#   'org': {'id': 6458,
#    'login': 'WebKit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/WebKit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6458?'}}]

# %% [markdown]
# That's really all you need for basic web access!  Isn't python GREAT!!?
#
# But here's a few other things...
#
# To check the "status code" returned by the web server (to error check and make sure you actually connected and retrieved the web document correctly), we use the .status_code attribute:

# %%
r = requests.get('http://httpbin.org/get')
r.status_code
# Out:
# 200

# %% [markdown]
# Note the 200, which means "It's all good!"
#
# But let's check what happens when things go bad:

# %%
bad_r = requests.get('http://httpbin.org/status/404')
bad_r.status_code
# Out:
# 404

# %% [markdown]
# A 404 error is "Not found".  That's bad.  So we should attempt to catch that.  We can use the raise_for_status() method, to tell us when something bad has happened.  It'll throw an error (which we could catch in a try/except block if we wanted to)

# %%
bad_r.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/7y/ysjj93z5227208lbzyddcjfw0000gn/T/ipykernel_48682/1508696525.py in <module>
# ----> 1 bad_r.raise_for_status()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 404 Client Error: NOT FOUND for url: http://httpbin.org/status/404

# %% [markdown]
# ACK!  Disaster!  Actually, let's practice our exception handling, so we can handle this gracefully:

# %%
def catch_me_some_web_exceptions(URL):
    my_request = requests.get(URL)
    try:
        my_request.raise_for_status()
        print("Your webpage", URL, "is waiting for you in the response variable!")
    except:
        print("Turns out", URL, "is a bad URL, bro.")
   
    # regardless of whether or not this works, return the request object
    return my_request

# %% [markdown]
# See how simple/useful catching exceptions is?  Let's try it out!

# %%
my_bad_request = catch_me_some_web_exceptions('http://httpbin.org/status/404')
# Out:
# Turns out http://httpbin.org/status/404 is a crappy URL, bro.

# %%
my_good_request = catch_me_some_web_exceptions('http://www.google.com')
# Out:
# Your webpage http://www.google.com is waiting for you in the response variable!

# %% [markdown]
# If you're really the curious sort, you can check out the HTTP respose headers using -- wait for it -- the .headers attribute

# %%
my_good_request.headers
# Out:
# {'Date': 'Tue, 07 Mar 2023 07:03:29 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'Content-Length': '6248', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2023-03-07-07; expires=Thu, 06-Apr-2023 07:03:29 GMT; path=/; domain=.google.com; Secure, AEC=ARSKqsKHtky15Tb8jjUv5O5onZ52u2DrXYiDwH_mMe06ekJQUEackXs7TAs; expires=Sun, 03-Sep-2023 07:03:29 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax, NID=511=E16IoJ9jotoQ6E2l9TkEu32-iU3C5Itxb7CrKzLJK3w9dxwQ9NlqN9dZLBd7cAxkQW-HiWBGoZj4JneMM_dljmVHQZZqumD2qO2wTcqEslCYaj8mNrE-aCdwO50KY7aMT4De8EnI7jscjd41iQgrGIIM_pcfTOJlmaOGQN3Ui60; expires=Wed, 06-Sep-2023 07:03:29 GMT; path=/; domain=.google.com; HttpOnly'}

# %% [markdown]
# You can access the headers like a dict, if you're so inclined:

# %%
my_good_request.headers['Content-Type']
# Out:
# 'text/html; charset=ISO-8859-1'

# %%
my_bad_request.headers['Content-Type']
# Out:
# 'text/html; charset=utf-8'

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.headers
# Out:
# {'Date': 'Tue, 07 Mar 2023 07:02:52 GMT', 'Content-Type': 'application/json', 'Content-Length': '311', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
my_good_request.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="Ht0LEa0a0dvVcPRUYAWP0g">(function(){window.google={kEI:\'weEGZMaPN_X1kPIP6K6m8A8\',kEXPI:\'0,1359409,6058,207,4804,2316,383,246,5,1129120,1625,1196074,867,379925,16114,28684,22430,1362,12319,17580,4998,13228,3847,35733,2711,2872,2891,3926,214,8220,30668,30022,15324,432,3,346,1244,1,5445,148,11323,2652,4,1528,2304,29062,13063,13660,2980,1457,9358,7428,5830,2527,4094,17,7579,1,11943,30211,2,14022,2373,342,21266,1758,5679,1020,31122,4569,6255,23421,1252,5835,14968,4332,7484,445,2,2,1,23827,799,10161,7381,2,3,15964,873,7829,1797,10008,7,1922,5784,3995,12415,8976,388,14375,2523,3782,2040,18159,20136,14,82,4641,11873,3692,109,1513,899,879,670,4307,3785,937,10169,4097,253,4134,988,3030,426,848,3857,499,481,1410,20,3,867,136,2549,55,4665,1804,567,6974,12,181,495,1152,1086,5,1648,109,96,465,566,142,1065,1281,6289,3699,1002,5425,84,165,212,2,375,530,1053,2034,1551,611,670,1,1169,2275,790,274,598,2036,393,308,1324,776,833,1635,1,917,3732,57,881,3,2838,153,229,84,1,165,4,71,342,95,50,53,4,1,3,427,271,217,219,122,68,606,4,127,760,232,1,577,11,888,5,62,3,665,476,421,2,297,453,85,5,8,655,8,250,4,107,926,4,4,434,342,568,3,15,2,361,652,4,32,338,89,380,378,64,186,2,298,42,1978,472,394,1739,2,401,128,5228369,5965,96,206,153,5995409,2803282,3311,141,795,19736,299,4,44,20730464,2920823,299198,4042142,1964,16673,2893,512,5738,12561,1539,603,744,2\',kBL:\'a2nQ\'};google.sn=\'webhp\';google.kHL=\'en\';})();(function(){\nvar f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}\nfunction n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};h=google.kEI;google.getEI=l;google.getLEI=m;google.ml=function(){return null};google.log=function(a,b,c,d,g){if(c=n(a,b,c,d,g)){a=new Image;var e=k.length;k[e]=a;a.onerror=a.onload=a.onabort=function(){delete k[e]};a.src=c}};google.logUrl=n;}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;widt ...

# %%
r.text
# Out:
# '{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-6406e19c-103e0c6a2bbdb1b8469a15aa"\n  }, \n  "origin": "172.250.225.33", \n  "url": "http://httpbin.org/get"\n}\n'

# %%
my_bad_request.text
# Out:
# ''

# %%
test = requests.get('https://github.com/thisshouldntbehere')

# %%
print(test.text)
# Out:
# Not Found

# %%
test.status_code
# Out:
# 404

# %%
enc = requests.get('https://www.twitter.com')

# %%
enc.headers

# %% [markdown]
# ## BeautifulSoup
# __BeautifulSoup parse an HTML string to a Document Object Model (DOM) and then navigates the DOM.__

# %% [markdown]
# You may need to do 'pip install beautifulsoup4'

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Simple table example

# %%
html_with_table = '''
<html>
   <body>
      <table cellpadding="3">
         <tr class="header"><th>Country</th><th>Capital</th><th>Population</th></tr>
         <tr><td>France</td><td>Paris</td><td>67000000</td></tr>
         <tr><td>Germany</td><td>Berlin</td><td>83000000</td></tr>
         <tr><td>Spain</td><td>Madrid</td><td>47000000</td></tr>
      </table>
   </body>
</html>'''

# %%
# Parse with beautiful soup (used to use 'lxml' as the parser)
soup = BeautifulSoup(html_with_table, 'html.parser')

table = soup.find('table')
table_rows = table.findAll('tr')
for table_row in table_rows:
    table_row_class_list = table_row.attrs.get('class', [])
    # print(table_row_class_list)
    if 'header' not in table_row_class_list:
        table_data_cells = table_row.findAll('td')
        country_cell = table_data_cells[0]
        capital_cell = table_data_cells[1]
        print(f"The capital of {country_cell.string} is {capital_cell.string}.")

# %% [markdown]
# ### Basketball draft example

# %%
r = requests.get("http://www.basketball-reference.com/draft/NBA_2003.html")

# %%
r.text

# %%
# Parse with beautiful soup (used to use 'lxml' as the parser)
soup = BeautifulSoup(r.content, 'html.parser') # returns bytes
soup1 = BeautifulSoup(r.text, 'html.parser')   # returns Unicode string, automatically decoded

# %%
all_rows = soup.findAll('tr')
all_tables = soup.findAll('table')

# %%
# the findAll method has an argument attrs 
# that takes a dictionary with attribute names and values

# find the 'table' elements that have an attribute 'id' with value 'stats'
main_table = soup.findAll('table', attrs={"id" : "stats"})[0]  # there is only one, pick it
main_body = main_table.find('tbody')

# %%
main_body

# %%
print(main_body.prettify())

# %%
# Useful to look at this in parallel with "inspecting" the table in Google Chrome

import re
url = "http://www.basketball-reference.com/draft/NBA_2003.html"

# Get the base URL: include first // but stop before further /
# r'[^/]+\/\/[^/]+' = match one or more characters that are not a slash, 
#                     match 2 slashes, match one or more characters that are not a slash,
base_url = re.match(r'[^/]+\/\/[^/]+', url).group(0)  
# Yields "http://www.basketball-reference.com"

r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

# method find finds the first occurrence of the tag; returns None is tag not present
main_body = main_table.find('tbody') # there is only one <tbody> tag in the doc, so OK

for player in main_body.findAll('tr'):
    player_data = player.findAll('td')
    if (len(player_data) > 0):
        player_a_tag = player_data[2].find('a') # Third row has the player name and URL
        # print(player_a_tag)
        player_name = player_a_tag.string
        # print(player_name)
        if (player_a_tag != None):
            player_link = player_a_tag.attrs['href'] # get URL of the player
        else:
            # If the link IS empty, assign the empty string
            player_link = ''
        print(f"{player_name}: {base_url}{player_link}")
