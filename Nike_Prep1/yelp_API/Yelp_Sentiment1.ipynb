# %% [markdown]
# ## Yelp Sentiment Analytics
# - API
# - Text Mining
#
# Client ID -
# JqCcYN_01Jpb1SOdY3qKnw
#
#
# API Key -
# 9DSH-f85EF1qiZ-c5A6mS2gH_4S66oGKPPXsUlC0T25VZpDmZ2C04FofnBFX-4knlpxLmH_LEQJkcFMXdBBPmJ39MsFf-PC5SegE-_Xv6Dc-WaFLZmfL89_0LP54ZHYx

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Final Code

# %%
url = 'https://api.yelp.com/v3/businesses/search'

# Set the request headers
headers = {
    'Authorization': 'Bearer 9DSH-f85EF1qiZ-c5A6mS2gH_4S66oGKPPXsUlC0T25VZpDmZ2C04FofnBFX-4knlpxLmH_LEQJkcFMXdBBPmJ39MsFf-PC5SegE-_Xv6Dc-WaFLZmfL89_0LP54ZHYx',
}

params = {
    'location': 'San Francisco',
    'term': 'restaurants',
    'limit': 5,  # Number of results to retrieve
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %%
json_search = response.json()

bus_names, reviews = [], []
for idx in range(len(json_search['businesses'])):
    url_bus = json_search['businesses'][idx]['url']
    response1 = requests.get(url_bus)
    print(json_search['businesses'][idx]['url'])
#    print(json_search['businesses'][idx], '\n\n\n') 
    soup = BeautifulSoup(response1.content, 'html.parser')
    li = soup.find_all('li', {'class': 'margin-b5__09f24__pTvws border-color--default__09f24__NPAKY'})
    
    for idx1 in range(len(li)):
        try:#works for 10 but not all li have this span class
            reviews.append(li[idx1].find_all('span', {'class': 'raw__09f24__T4Ezm'})[0].text)
            bus_names.append(json_search['businesses'][idx]['name'])
            print('Review Added for {}'.format(json_search['businesses'][idx]['name']))
        except IndexError:
            continue
    print('\n\n')
print('Reviews Added from API Query')
# Out:
# https://www.yelp.com/biz/kiln-san-francisco-3?adjust_creative=JqCcYN_01Jpb1SOdY3qKnw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JqCcYN_01Jpb1SOdY3qKnw
# Review Added for Kiln
# Review Added for Kiln
# Review Added for Kiln
# Review Added for Kiln
# Review Added for Kiln
#
#
#
# https://www.yelp.com/biz/mattina-san-francisco?adjust_creative=JqCcYN_01Jpb1SOdY3qKnw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JqCcYN_01Jpb1SOdY3qKnw
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
# Review Added for Mattina
#
#
#
# https://www.yelp.com/biz/starbelly-san-francisco?adjust_creative=JqCcYN_01Jpb1SOdY3qKnw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JqCcYN_01Jpb1SOdY3qKnw
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
# Review Added for Starbelly
#
#
#
# https://www.yelp.com/biz/bottega-san-francisco-2?adjust_creative=JqCcYN_01Jpb1SOdY3qKnw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JqCcYN_01Jpb1SOdY3qKnw
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
# Review Added for Bottega
#
#
#
# https://www.yelp.com/biz/marufuku-ramen-san-francisco-5?adjust_creative=JqCcYN_01Jpb1SOdY3qKnw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JqCcYN_01Jpb1SOdY3qKnw
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
# Review Added for Marufuku Ramen
